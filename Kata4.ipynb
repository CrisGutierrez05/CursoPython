# %% [markdown]
# ## Ejercicio 1: Transformar cadenas

# %%
text = """Interesting facts about the Moon. The Moon is Earth's only satellite. There are several interesting facts about the Moon and how it affects life here on Earth. 
On average, the Moon moves 4cm away from the Earth every year. This yearly drift is not significant enough to cause immediate effects on Earth. The highest daylight temperature of the Moon is 127 C."""

# %% [markdown]
# Primero, divide el texto en cada oración para trabajar con su contenido:

# %%
text = """Interesting facts about the Moon.\nThe Moon is Earth's only satellite.\nThere are several interesting facts about the Moon and how it affects life here on Earth.\n
On average, the Moon moves 4cm away from the Earth every year.\nThis yearly drift is not significant enough to cause immediate effects on Earth.\nThe highest daylight temperature of the Moon is 127 C."""
partes = text.split('\n')
keywords = ['average', 'temperature', 'cm']
print(partes)
for oracion in partes:
    for keyword in keywords:
        if keyword in oracion:
            print(oracion.replace('C', 'Celsius'))
            break
# Out:
# ['Interesting facts about the Moon.', "The Moon is Earth's only satellite.", 'There are several interesting facts about the Moon and how it affects life here on Earth.', '', 'On average, the Moon moves 4cm away from the Earth every year.', 'This yearly drift is not significant enough to cause immediate effects on Earth.', 'The highest daylight temperature of the Moon is 127 C.']
# On average, the Moon moves 4cm away from the Earth every year.
# The highest daylight temperature of the Moon is 127 Celsius.

# %%
text = """Interesting facts about the Moon.\nThe Moon is Earth's only satellite.\nThere are several interesting facts about the Moon and how it affects life here on Earth.\n
On average, the Moon moves 4cm away from the Earth every year.\nThis yearly drift is not significant enough to cause immediate effects on Earth.\nThe highest daylight temperature of the Moon is 127 C."""
partes = text.split("\n")
keywords = ["average", "cm", "temperature"]

for oracion in partes:
    for keyword in keywords:
        if keyword in oracion:
            print(oracion)
            break
# Out:
# On average, the Moon moves 4cm away from the Earth every year.
# The highest daylight temperature of the Moon is 127 C.

# %% [markdown]
# ## Ejercicio 2: Formateando Cadenas

# %%
# Datos con los que vas a trabajar
name = "Moon"
gravity = 0.00162 # in kms
planet = "Earth"

titulo = f'Valores de gravedad de {name}'

#Plantilla
datos = f"""{'-'*100}
Planeta = {planet}
Gravedad en {name}: {gravity * 1000} m/s"""

union = f"""{titulo.title()}
{datos}"""
print(union)
# Out:
# Valores De Gravedad De Moon
# ----------------------------------------------------------------------------------------------------
# Planeta = Earth
# Gravedad en Moon: 1.6199999999999999 m/s

# %%
# Datos con los que vas a trabajar
name = "Ganímedes"
gravity = 0.00143 # in kms
planet = "Marte"

titulo = f'Valores de gravedad de {name}'

#Plantilla
datos = f"""{'-'*100}
Planeta = {planet}
Gravedad en {name}: {gravity * 1000} m/s"""

union = f"""{titulo.title()}
{datos}"""
print(union)
# Out:
# Valores De Gravedad De Ganímedes
# ----------------------------------------------------------------------------------------------------
# Planeta = Marte
# Gravedad en Ganímedes: 1.4300000000000002 m/s

# %%
#Otros datos de muestra:
planeta = 'Marte'
gravedad = 0.00143
nombre = 'Ganímedes'

plantillanew = """
Datos de gravedad en {nombre}
----------------------------------------------------
Planeta: {planeta}
Gravedad en {nombre}: {gravedad} m/s
"""
print(plantillanew.format(nombre= nombre, planeta=planeta, gravedad= gravedad))
# Out:
# Datos de gravedad en Ganímedes
# ----------------------------------------------------
# Planeta: Marte
# Gravedad en Ganímedes: 0.00143 m/s
