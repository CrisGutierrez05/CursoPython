# %% [markdown]
# # Ejercicio Kata 3

# %% [markdown]
# Añadir el código necesario para crear una variable que guarde la velocidad del asteroide.
#
# Escribe una expresión de prueba para calcular si necesita una advertencia.
#
# Agregue las instrucciones que se ejecutarán si la expresión de prueba es true o false.

# %%
Velocidad_asteroide = 49 
velocidad_limite = 25
if Velocidad_asteroide > velocidad_limite:
    print("Alerta un asteroide está acercandose al planeta Tierra demasiado rápido")
else:
    print("El asteroide no presenta una amenaza ")
# Out:
# Alerta un asteroide está acercandose al planeta Tierra demasiado rápido

# %% [markdown]
# Agrega el código para crear una variable para un asteroide que viaja a 19 km/s
#
# Escribe varias expresiones de prueba para determinar si puedes ver el rayo de luz desde la tierra
#
# Agrega las instrucciones que se ejecutarán si las expresiones de prueba son True o False

# %%
Velocidad_asteroide = 26 
velocidad_luz = 20
velocidad_limite = 25
if Velocidad_asteroide >= velocidad_luz:
    if Velocidad_asteroide >= velocidad_limite:
        print("¡Alerta un asteroide está acercandose al planeta Tierra demasiado rápido!")
    else:
            print("¡Un asteroide será visibe en el cielo, obsérvalo!")
elif Velocidad_asteroide < velocidad_luz:
    print("El asteroide no será visible")
# Out:
# ¡Alerta un asteroide está acercandose al planeta Tierra demasiado rápido!

# %% [markdown]
# Agrega el código para crear nuevas variables para la velocidad y el tamaño del asteroide
#
# Para probar el código, prueba con varias velocidades y tamaños
#
# Escribe varias expresiones de prueba o combinaciones de expresiones de prueba para determinar qué mensaje se debe enviar a Tierra.

# %%
Velocidad_asteroide = 26
velocidad_luz = 20
velocidad_limite = 25
tamaño_asteroide = 24
tamaño_limite = 25
if Velocidad_asteroide >= velocidad_luz and tamaño_asteroide < tamaño_limite:
    if Velocidad_asteroide >= velocidad_limite:
        print("¡Alerta! Asteroide aproximándose a una velocidad de " + str(Velocidad_asteroide) + " km/h a la Tierra ")
    else:
        print("¡Atención! ¡Un asteroide será visible en el cielo, obsérvalo! ")
elif Velocidad_asteroide < velocidad_luz:
    print("El Asteroide no será visible ")
elif Velocidad_asteroide >= velocidad_limite and tamaño_asteroide >= tamaño_limite:
    print("¡Alerta! Asteroide de " + str(tamaño_asteroide) + " metros se acerca a " + str(Velocidad_asteroide) + " km/h " )
elif Velocidad_asteroide >= velocidad_limite or tamaño_asteroide >= tamaño_limite:
    print("¡Alerta! Asteroide de " + str(tamaño_asteroide) + " metros se acerca a " + str(Velocidad_asteroide) + " km/h ")
# Out:
# ¡Alerta! Asteroide aproximándose a una velocidad de 26 km/h a la Tierra
